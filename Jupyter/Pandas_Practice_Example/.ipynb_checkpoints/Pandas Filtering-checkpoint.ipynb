# %% [markdown]
# ## Pandas Filtering:
# This is used to filter out certain rows and columns that follows a certain condition.

# %%
import pandas as pd
people={'first':['Akhil','Anusree','Ancy'],
       'second':['Muraleedharan','Muraleedharan','S Kumar'],
       'email':['akhil@gmail.com','anu@gmail.com','ancy@gmail.com']}
df=pd.DataFrame(people)
df
# Out:
#      first         second            email
# 0    Akhil  Muraleedharan  akhil@gmail.com
# 1  Anusree  Muraleedharan    anu@gmail.com
# 2     Ancy        S Kumar   ancy@gmail.com

# %%
#filtering done using normal indexing method
filt=(df['second']=='Muraleedharan')
df[filt]
# Out:
#      first         second            email
# 0    Akhil  Muraleedharan  akhil@gmail.com
# 1  Anusree  Muraleedharan    anu@gmail.com

# %%
#filteing done using loc function
df.loc[filt,'email']
# Out:
# 0    akhil@gmail.com
# 1      anu@gmail.com
# Name: email, dtype: object

# %%
#operator 'and' can't be used in pandas '&' is used instead
filt1=(df['first']=='Akhil') & (df['second']=='Muraleedharan' )
df.loc[filt1,'email']
# Out:
# 0    akhil@gmail.com
# Name: email, dtype: object

# %%
filt1=(df['first']=='Akhil') | (df['second']=='Muraleedharan' )
df.loc[filt1,'email']
# Out:
# 0    akhil@gmail.com
# 1      anu@gmail.com
# Name: email, dtype: object

# %%
df1=pd.read_csv('survey_results_public.csv')
df1.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
#filtering out people with a salary of more than 80000
hisal=(df1['ConvertedCompYearly'] > 80000)
df1.loc[hisal]
# Out:
#        ResponseId                                         MainBranch  \
# 18             19  I am not primarily a developer, but I write co...
# 26             27  I am not primarily a developer, but I write co...
# 31             32                     I am a developer by profession
# 36             37                     I am a developer by profession
# 37             38                     I am a developer by profession
# ...           ...                                                ...
# 83430       83431                     I am a developer by profession
# 83432       83433                     I am a developer by profession
# 83434       83435                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                 Employment                   Country              US_State  \
# ...

# %%
df1['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Dominica                                                    1
# Papua New Guinea                                            1
# Liechtenstein                                               1
# Tuvalu                                                      1
# Brunei Darussalam                                           1
# Name: Country, Length: 181, dtype: int64

# %%
# New list is made with names of certain countries
countries=['Dominica','Papua New Guinea', 'Tuvalu','Brunei Darussalam']
filt2=(df1['Country'].isin(countries))# isin method is used to check whether the elements in the given list is present in the dataframe or not.
df1.loc[filt2,['MainBranch','Country']]
# Out:
#                                               MainBranch            Country
# 6164                      I am a developer by profession           Dominica
# 26463  I am not primarily a developer, but I write co...  Brunei Darussalam
# 61690             I am a student who is learning to code             Tuvalu
# 72812             I am a student who is learning to code   Papua New Guinea

# %%
# Find out the elements that contains a particular string in it.
master=df1['EdLevel'].str.contains('M.A.',na=False)
df1.loc[master]
# Out:
#        ResponseId                              MainBranch  \
# 3               4          I am a developer by profession
# 4               5          I am a developer by profession
# 9              10          I am a developer by profession
# 12             13          I am a developer by profession
# 13             14  I am a student who is learning to code
# ...           ...                                     ...
# 83419       83420          I am a developer by profession
# 83420       83421          I am a developer by profession
# 83423       83424          I am a developer by profession
# 83428       83429          I am a developer by profession
# 83430       83431          I am a developer by profession
#
#                                               Employment  \
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# 9                                     Employed full-time
# ...
