# %% [markdown]
# ## Indexing:
# Here we are going to deal with different types of indexing using pandas

# %%
import pandas as pd
people={'first':['Akhil','Muraleedharan','Ancy'],
        'last':['Muraleedharan','MV','S Kumar'],
       'email':['anakhil6@gmail.com','muraleedharanaaa@gmail.com','ancy.3a6@gmail.com']}
df=pd.DataFrame(people)

#Setting email as the index of the data frame
df.set_index('email', inplace=True) #inplace=True is used to permanently apply the changes to the data frame
df
# Out:
#                                     first           last
# email
# anakhil6@gmail.com                  Akhil  Muraleedharan
# muraleedharanaaa@gmail.com  Muraleedharan             MV
# ancy.3a6@gmail.com                   Ancy        S Kumar

# %%
df.loc['anakhil6@gmail.com']
# Out:
# first            Akhil
# last     Muraleedharan
# Name: anakhil6@gmail.com, dtype: object

# %% [markdown]
# <u>**Reading the schema file and setting 'qid' as the index**</u>

# %%
df_schema=pd.read_csv('survey_results_schema.csv',index_col=0)
df_schema.head()
# Out:
#             qname                                           question  \
# qid
# QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12    MetaInfo                                  Browser Meta Info
# QID1           S1  <span style="font-size:22px; font-family: aria...
# QID2   MainBranch  Which of the following options best describes ...
# QID24  Employment  Which of the following best describes your cur...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# QID1        False    DB       TB
# QID2         True    MC     SAVR
# QID24       False    MC     MAVR

# %%
df_schema.sort_index().head()
# Out:
#               qname                                           question  \
# qid
# QID1             S1  <span style="font-size:22px; font-family: aria...
# QID100  SOVisitFreq  How frequently would you say you visit Stack O...
# QID101    SOAccount              Do you have a Stack Overflow account?
# QID102   SOPartFreq  How frequently would you say you participate i...
# QID106       SOComm  Do you consider yourself a member of the Stack...
#
#         force_resp type selector
# qid
# QID1         False   DB       TB
# QID100       False   MC     MAVR
# QID101       False   MC     MAVR
# QID102       False   MC     MAVR
# QID106       False   MC     MAVR

# %%
# .sort_index() method does not make changes in the real data frame
df_schema.sort_index(ascending=False).head()
# Out:
#             qname                                           question  \
# qid
# QID91          S4  <span style="font-size:22px; font-family: aria...
# QID9   UK_Country  In which part of the United Kingdom do you liv...
# QID71       OpSys  What is the primary operating system in which ...
# QID7     US_State  <p>In which state or territory of the USA do y...
# QID61          S3  <span style="font-size:22px; font-family: aria...
#
#        force_resp type selector
# qid
# QID91       False   DB       TB
# QID9        False   MC       DL
# QID71       False   MC     SAVR
# QID7        False   MC       DL
# QID61       False   DB       TB

# %%
#inplace command can be used to make permanent changes in the data frame
df_schema.sort_index(inplace=True)
df_schema
# Out:
#                      qname                                           question  \
# qid
# QID1                    S1  <span style="font-size:22px; font-family: aria...
# QID100         SOVisitFreq  How frequently would you say you visit Stack O...
# QID101           SOAccount              Do you have a Stack Overflow account?
# QID102          SOPartFreq  How frequently would you say you participate i...
# QID106              SOComm  Do you consider yourself a member of the Stack...
# QID12             MetaInfo                                  Browser Meta Info
# QID121                  S5  <span style="font-size:22px; font-family: aria...
# QID122              Gender  Which of the following describe you, if any? P...
# QID124       Accessibility  Which of the following describe you, if any? P...
# QID125        MentalHealth  Which of the following describe you, if any? P...
# QID126           Ethnicity  Which of the following describe you, if any? P...
# QID127                 Age                                  What is your age?
# QID131                  S6  <span style="font-size:22px;"><strong>Final Qu...
# QID132        SurveyLength  How do you feel about the length of the survey...
# QID133          SurveyEase  How easy or difficult was this survey to compl...
# QID136           Sexuality  Which of the following describe you, if any? P...
# QID149          Age1stCode  At what age did you write your first line of c...
# QID153               Trans                    Do you identify as transgender?
# QID16                   S0  <div><span style="font-size:19px;"><strong>Hel...
# QID190                  S2  <span style="font-size:22px; font-family: aria...
# QID2            MainBranch  Which of the following options best describes ...
# QID233            Language  Which <b>programming, scripting, and markup la...
# QID24           Employment  Which of the following best describes your cur...
# QID243            NEWStuck  What do you do when you get stuck on a problem...
# QID25              EdLevel  Which of the following best describes the high...
# QID262            Database  Which <b>database environments </b>have you do...
# QID263            Platform  Which <b>cloud platforms</b> have you done ext...
# QID264            Webframe  Which <strong>web frameworks </strong><span st...
# QID265            MiscTech  Which <b>other frameworks and libraries</b> ha...
# QID266          NEWSOSites  Which of the following Stack Overflow sites ha...
# QID267       NEWOtherComms  Are you a member of any other online developer...
# QID268  NEWOtherCommsNames  Please name up to 5 other online developer com...
# QID274      NEWCollabTools  Which <strong>development environments</strong...
# QID275           ToolsTech  Which <strong>tools</strong> have you done ext...
# QID276           LearnCode  How did you learn to code? Select all that apply.
# QID29              OrgSize  Approximately how many people are employed by ...
# QID31              DevType  Which of the following describes your current ...
# QID32            YearsCode  Including any education, how many years have y...
# QID34         YearsCodePro  NOT including education, how many years have y...
# QID50             Currency  Which currency do you use day-to-day? If your ...
# QID51            CompTotal  What is your current total compensation (salar...
# QID52             CompFreq   Is that compensation weekly, monthly, or yearly?
# QID6               Country  Where do you live? <span style="font-weight: b...
# QID61                   S3  <span style="font-size:22px; font-family: aria...
# QID7              US_State  <p>In which state or territory of the USA do y...
# QID71                OpSys  What is the primary operating system in which ...
# QID9            UK_Country  In which part of the United Kingdom do you liv...
# QID91                   S4  <span style="font-size:22px; font-family: aria...
#
#         force_resp    type selector
# qid
# QID1         False      DB       TB
# QID100       False      MC     MAVR
# QID101       False      MC     MAVR
# QID102       False      MC     MAVR
# QID106       False      MC     MAVR
# QID12        False    Meta  Browser
# QID121       False      DB       TB
# QID122       False      MC     MAVR
# QID124       False      MC     MAVR
# QID125       False      MC     MAVR
# QID126       False      MC     MAVR
# QID127       False      MC     MAVR
# QID131       False      DB       TB
# QID132       False      MC     MAVR
# QID133       False      MC     MAVR
# QID136       False      MC     MAVR
# QID149       False      MC     MAVR
# QID153       False      MC     MAVR
# QID16        False      DB       TB
# QID190       False      DB       TB
# QID2          True      MC     SAVR
# QID233       False  Matrix   Likert
# QID24        False      MC     MAVR
# QID243       False      MC     MAVR
# QID25        False      MC     SAVR
# QID262       False  Matrix   Likert
# QID263       False  Matrix   Likert
# QID264       False  Matrix   Likert
# QID265       False  Matrix   Likert
# QID266       False      MC     MAVR
# QID267       False      MC     MAVR
# QID268       False  Matrix   Likert
# QID274       False  Matrix   Likert
# QID275       False  Matrix   Likert
# QID276       False      MC     MAVR
# QID29        False      MC     MAVR
# QID31        False      MC     MAVR
# QID32        False      MC       DL
# QID34        False      MC       DL
# QID50         True      MC       SB
# QID51        False      TE       SL
# QID52        False      MC     MAVR
# QID6          True      MC       DL
# QID61        False      DB       TB
# QID7         False      MC       DL
# QID71        False      MC     SAVR
# QID9         False      MC       DL
# QID91        False      DB       TB
